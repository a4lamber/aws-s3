# %% [markdown]
# # Fuzzy comparison
# The goal of this tool is to collectively solve how to merge multiple data source together. In mimic 3 and mimic 4, it shares similar filenames `patients.csv` and `patients.csv.gz`. Also inside each file, it might have columns `icd_code` in mimic3 and `icd9_code` in mimic4.
# The current solution i am trying out is to use fuzzy comparison to get the best score.

# %%
import pandas as pd
import json
from fuzzywuzzy import fuzz,process
import ipywidgets as widgets
# Out:
# /Users/yixiangzhang/Documents/AWS_SAA_C03/.venv/lib/python3.11/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# open mimic_3

# %%
with open("data/mimic_3.json", "r") as f:
    mimic_3 = json.load(f)

print(mimic_3)
# Out:
# {'PROCEDUREEVENTS_MV': {'Unnamed: 0': 'int', 'row_id': 'int', 'subject_id': 'int', 'hadm_id': 'int', 'icustay_id': 'int', 'starttime': 'datetime', 'endtime': 'datetime', 'itemid': 'datetime', 'value': 'int', 'valueuom': 'string', 'location': 'string', 'locationcategory': 'string', 'storetime': 'datetime', 'cgid': 'int', 'orderid': 'int', 'linkorderid': 'int', 'ordercategoryname': 'string', 'secondaryordercategoryname': None, 'ordercategorydescription': 'string', 'isopenbag': 'int', 'continueinnextdept': 'int', 'cancelreason': 'int', 'statusdescription': 'string', 'comments_editedby': 'string', 'comments_canceledby': 'string', 'comments_date': 'datetime', 'filepath': '../basic_filtered_data/mimic-iii-demo/PROCEDUREEVENTS_MV.csv'}, 'CALLOUT': {'Unnamed: 0': 'int', 'row_id': 'int', 'subject_id': 'int', 'hadm_id': 'int', 'submit_wardid': 'int', 'submit_careunit': 'string', 'curr_wardid': 'int', 'curr_careunit': 'string', 'callout_wardid': 'int', 'callout_service': 'string', 'request_tele': 'int', 'request_resp': 'int', 'request_cdiff': 'int', 'request_mrsa': 'int', 'request_vre': 'int', 'callout_status': 'string', 'callout_outcome': 'string', 'discharge_wardid': 'int', 'acknowledge_status': 'string', 'createtime': 'datetime', 'updatetime': 'datetime', 'acknowledgetime': 'datetime', 'outcometime': 'datetime', 'firstreservationtime': 'datetime', 'currentreservationtime': 'datetime', 'filepath': '../basic_filtered_data/mimic-iii-demo/CALLOUT.csv'}, 'D_CPT': {'Unnamed: 0': 'int', 'row_id': 'int', 'category': 'int', 'sectionrange': 'string', 'sectionheader': 'string', 'subsectionrange': 'string', 'subsectionheader': 'string', 'codesuffix': 'string', 'mincodeinsubsection': 'int', 'maxcodeinsubsection': 'int', 'filepath': '../basic_filtered_data/mimic-iii-demo/D_CPT.csv'}, 'D_ITEMS': {'Unnamed: 0': 'int', 'row_id': 'int', 'itemid': 'int', 'label': 'string', 'abbreviation': 'string', 'dbsource': 'string', 'linksto': 'string', 'category': 'string', 'unitname': 'string', 'param_type': 'string', 'conceptid': None, 'filepath': '../basic_filtered_data/mimic-iii-demo/D_ITEMS.csv'}, 'CAREGIVERS': {'Unnamed: 0': 'int', 'row_id': 'int', 'cgid': 'int', 'label': 'string', 'description': 'string', 'filepath': '../basic_filtered_data/mimic-iii-demo/CAREGIVERS.csv'}, 'MICROBIOLOGYEVENTS': {'Unnamed: 0': 'int', 'row_id': 'datetime', 'subject_id': 'int', 'hadm_id': 'int', 'chartdate': 'datetime', 'charttime': 'datetime', 'spec_itemid': 'int', 'spec_type_desc': 'string', 'org_itemid': 'int', 'org_name': 'string', 'isolate_num': 'int', 'ab_itemid': 'int', 'ab_name': 'string', 'dilution_text': 'string', 'dilution_comparison': 'string', 'dilution_value': 'int', 'interpretation': 'string', 'filepath': '../basic_filtered_data/mimic-iii-demo/MICROBIOLOGYEVENTS.csv'}, 'LABEVENTS': {'Unnamed: 0': 'int', 'row_id': 'int', 'subject_id': 'int', 'hadm_id': 'int', 'itemid': 'int', 'charttime': 'datetime', 'value': 'string', 'valuenum': 'float', 'valueuom': 'string', 'flag': 'string', 'filepath': '../basic_filtered_data/mimic-iii-demo/LABEVENTS.csv'}, 'INPUTEVENTS_CV': {'Unnamed: 0': 'int', 'row_id': 'int', 'subject_id': 'int', 'hadm_id': 'int', 'icustay_id': 'int', 'charttime': 'datetime', 'itemid': 'int', 'amount': 'float', 'amountuom': 'string', 'rate': 'float', 'rateuom': 'string', 'storetime': 'datetime', 'cgid': 'int', 'orderid': 'int', 'linkorderid': 'int', 'stopped': 'string', 'newbottle': 'int', 'originalamount': 'float', 'originalamountuom': 'string', 'originalroute': 'string', 'originalrate': 'float', 'originalrateuom': 'string', 'originalsite': 'string', 'filepath': '../basic_filtered_data/mimic-iii-demo/INPUTEVENTS_CV.csv'}, 'ADMISSIONS': {'Unnamed: 0': 'int', 'row_id': 'int', 'subject_id': 'int', 'hadm_id': 'int', 'admittime': 'datetime', 'dischtime': 'datetime', 'deathtime': 'datetime', 'admission_type': 'string', 'admission_location': 'string', 'discharge_location': 'string', 'insurance': 'string', 'language': 'string', 'religion': 'string', 'marital_sta ...

# %% [markdown]
# open mimic_4 and merge them

# %%
with open("data/mimic_4_ed.json", "r") as f:
    mimic_4_ed = json.load(f)

with open("data/mimic_4_hosp.json", "r") as f:
    mimic_4_hosp = json.load(f)

with open("data/mimic_4_icu.json", "r") as f:
    mimic_4_icu = json.load(f)


mimic_4 = dict()
mimic_4.update(mimic_4_ed)
mimic_4.update(mimic_4_icu)
mimic_4.update(mimic_4_hosp)

# %%
import json

# Write dictionary to file as JSON
with open('./data/mimic_4.json', 'w') as f:
    json.dump(mimic_4, f)

# %% [markdown]
# ## Display mimic3

# %%
mimic_3_options = list(mimic_3.keys())

dropdown_mimic_3 = widgets.Dropdown(options = mimic_3_options, 
                                    value = mimic_3_options[0],
                                    description = "table name: ",
                                    disabled = False)



def display_value(key):
    value = mimic_3[key]
    print(key)
    for minikey,datatype in value.items():
        print(f"{minikey:<30}{datatype}")


widgets.interact(display_value,key = dropdown_mimic_3)
# Out:
# interactive(children=(Dropdown(description='table name: ', options=('PROCEDUREEVENTS_MV', 'CALLOUT', 'D_CPT', …
# <function __main__.display_value(key)>

# %% [markdown]
# # Table-level cross reference
# for every table in mimic 3, find the counterpart in mimic_4 with fuzzy match

# %%
def get_matched_table(json_1,json_2, num_best_match = 3):
    """
    input two json files about the metadata information, returns a dataframe
    with five columns

    :param _type_ json_1: _description_
    :param _type_ json_2: _description_
    :param int num_best_match: _description_, defaults to 3
    :return _type_: _description_
    """
    
    # obtain the keys of json
    tables_1 = list(json_1.keys())
    tables_2 = list(json_2.keys())
    
    output = [[0 for j in range(5)] for i in range(len(tables_1))]
    
    # lower case all of the data
    tables_2_lower = [i.lower() for i in tables_2]

    for i,table_1 in enumerate(tables_1):
        matches = process.extract(table_1.lower(),tables_2_lower,limit = num_best_match)
        print(f"Best three matches for {table_1}:")
        for match in matches:
            print(f"{match[0]:<10} Confidence: {match[1]}%")
        print()
        # append to output
        output[i][0] = table_1
        output[i][1] = json_1[table_1]["filepath"]
        output[i][2] = matches[0][0]
        output[i][3] = json_2[matches[0][0]]["filepath"]
        output[i][4] = matches[0][1]
    
    df = pd.DataFrame(output,columns=["table_mimic_3",
                                      "filepath_mimic3",
                                      "table_mimic_4",
                                      "filepath_mimic4",
                                      "confidence"])
    return df

df_table_matches = get_matched_table(mimic_3,
                  mimic_4)
# Out:
# Best three matches for PROCEDUREEVENTS_MV:
# procedureevents.csv Confidence: 86%
# procedures_icd.csv Confidence: 67%
# ingredientevents.csv Confidence: 58%
#
# Best three matches for CALLOUT:
# outputevents.csv Confidence: 49%
# chartevents.csv Confidence: 39%
# datetimeevents.csv Confidence: 37%
#
# Best three matches for D_CPT:
# d_hcpcs.csv Confidence: 72%
# d_items.csv Confidence: 54%
# prescriptions.csv Confidence: 54%
#
# Best three matches for D_ITEMS:
# d_items.csv Confidence: 90%
# d_labitems.csv Confidence: 67%
# datetimeevents.csv Confidence: 51%
#
# Best three matches for CAREGIVERS:
# chartevents.csv Confidence: 56%
# labevents.csv Confidence: 49%
# procedureevents.csv Confidence: 45%
#
# Best three matches for MICROBIOLOGYEVENTS:
# microbiologyevents.csv Confidence: 95%
# labevents.csv Confidence: 49%
# chartevents.csv Confidence: 48%
#
# Best three matches for LABEVENTS:
# labevents.csv Confidence: 95%
# chartevents.csv Confidence: 70%
# datetimeevents.csv Confidence: 60%
#
# Best three matches for INPUTEVENTS_CV:
# inputevents.csv Confidence: 90%
# outputevents.csv Confidence: 73%
# ingredientevents.csv Confidence: 65%
#
# Best three matches for ADMISSIONS:
# admissions.csv Confidence: 95%
# prescriptions.csv Confidence: 45%
# vitalsign.csv Confidence: 43%
#
# Best three matches for D_LABITEMS:
# d_labitems.csv Confidence: 95%
# d_items.csv Confidence: 67%
# datetimeevents.csv Confidence: 45%
#
# Best three matches for DATETIMEEVENTS:
# datetimeevents.csv Confidence: 95%
# chartevents.csv Confidence: 55%
# patients.csv Confidence: 54%
#
# Best three matches for PRESCRIPTIONS:
# prescriptions.csv Confidence: 95%
# medrecon.csv Confidence: 48%
# d_icd_procedures.csv Confidence: 45%
#
# Best three matches for PROCEDURES_ICD:
# procedures_icd.csv Confidence: 95%
# procedureevents.csv Confidence: 67%
# d_icd_procedures.csv Confidence: 65%
#
# Best three matches for CHARTEVENTS:
# chartevents.csv Confidence: 95%
# labevents.csv Confidence: 64%
# inputevents.csv Confidence: 59%
#
# Best three matches for TRANSFERS:
# transfers.csv Confidence: 95%
# d_icd_diagnoses.csv Confidence: 53%
# diagnoses_icd.csv Confidence: 50%
#
# Best three matches for DIAGNOSES_ICD:
# diagnoses_icd.csv Confidence: 95%
# diagnosis.csv Confidence: 69%
# d_icd_diagnoses.csv Confidence: 62%
#
# Best three matches for SERVICES:
# services.csv Confidence: 90%
# hcpcsevents.csv Confidence: 57%
# transfers.csv Confidence: 56%
#
# Best three matches for DRGCODES:
# drgcodes.csv Confidence: 90%
# medrecon.csv Confidence: 50%
# services.csv Confidence: 49%
#
# Best three matches for OUTPUTEVENTS:
# outputevents.csv Confidence: 95%
# inputevents.csv Confidence: 67%
# datetimeevents.csv Confidence: 60%
#
# Best three matches for PATIENTS:
# patients.csv Confidence: 90%
# prescriptions.csv Confidence: 57%
# ingredientevents.csv Confidence: 56%
#
# Best three matches for D_ICD_DIAGNOSES:
# d_icd_diagnoses.csv Confidence: 95%
# diagnosis.csv Confidence: 61%
# diagnoses_icd.csv Confidence: 59%
#
# Best three matches for ICUSTAYS:
# icustays.csv Confidence: 90%
# edstays.csv Confidence: 60%
# vitalsign.csv Confidence: 45%
#
# Best three matches for INPUTEVENTS_MV:
# inputevents.csv Confidence: 83%
# outputevents.csv Confidence: 67%
# ingredientevents.csv Confidence: 59%
#
# Best three matches for D_ICD_PROCEDURES:
# d_icd_procedures.csv Confidence: 95%
# procedures_icd.csv Confidence: 62%
# procedureevents.csv Confidence: 60%
#
# Best three matches for CPTEVENTS:
# inputevents.csv Confidence: 80%
# outputevents.csv Confidence: 80%
# ingredientevents.csv Confidence: 70%

# %%
df_table_matches
# Out:
#          table_mimic_3                                    filepath_mimic3
# 0   PROCEDUREEVENTS_MV  ../basic_filtered_data/mimic-iii-demo/PROCEDUR...  \
# 1              CALLOUT  ../basic_filtered_data/mimic-iii-demo/CALLOUT.csv
# 2                D_CPT    ../basic_filtered_data/mimic-iii-demo/D_CPT.csv
# 3              D_ITEMS  ../basic_filtered_data/mimic-iii-demo/D_ITEMS.csv
# 4           CAREGIVERS  ../basic_filtered_data/mimic-iii-demo/CAREGIVE...
# 5   MICROBIOLOGYEVENTS  ../basic_filtered_data/mimic-iii-demo/MICROBIO...
# 6            LABEVENTS  ../basic_filtered_data/mimic-iii-demo/LABEVENT...
# 7       INPUTEVENTS_CV  ../basic_filtered_data/mimic-iii-demo/INPUTEVE...
# 8           ADMISSIONS  ../basic_filtered_data/mimic-iii-demo/ADMISSIO...
# 9           D_LABITEMS  ../basic_filtered_data/mimic-iii-demo/D_LABITE...
# 10      DATETIMEEVENTS  ../basic_filtered_data/mimic-iii-demo/DATETIME...
# 11       PRESCRIPTIONS  ../basic_filtered_data/mimic-iii-demo/PRESCRIP...
# 12      PROCEDURES_ICD  ../basic_filtered_data/mimic-iii-demo/PROCEDUR...
# 13         CHARTEVENTS  ../basic_filtered_data/mimic-iii-demo/CHARTEVE...
# 14           TRANSFERS  ../basic_filtered_data/mimic-iii-demo/TRANSFER...
# 15       DIAGNOSES_ICD  ../basic_filtered_data/mimic-iii-demo/DIAGNOSE...
# 16            SERVICES  ../basic_filtered_data/mimic-iii-demo/SERVICES...
# 17            DRGCODES  ../basic_filtered_data/mimic-iii-demo/DRGCODES...
# 18        OUTPUTEVENTS  ../basic_filtered_data/mimic-iii-demo/OUTPUTEV...
# 19            PATIENTS  ../basic_filtered_data/mimic-iii-demo/PATIENTS...
# 20     D_ICD_DIAGNOSES  ../basic_filtered_data/mimic-iii-demo/D_ICD_DI...
# 21            ICUSTAYS  ../basic_filtered_data/mimic-iii-demo/ICUSTAYS...
# 22      INPUTEVENTS_MV  ../basic_filtered_data/mimic-iii-demo/INPUTEVE...
# 23    D_ICD_PROCEDURES  ../basic_filtered_data/mimic-iii-demo/D_ICD_PR...
# 24           CPTEVENTS  ../basic_filtered_data/mimic-iii-demo/CPTEVENT...
#
#              table_mimic_4                                    filepath_mimic4
# 0      procedureevents.csv  ../basic_filtered_data/mimic-iv-demo/2.2/icu/p...  \
# 1         outputevents.csv  ../basic_filtered_data/mimic-iv-demo/2.2/icu/o...
# 2              d_hcpcs.csv  ../basic_filtered_data/mimic-iv-demo/2.2/hosp/...
# 3              d_items.csv  ../basic_filtered_data/mimic-iv-demo/2.2/icu/d...
# 4          chartevents.csv  ../basic_filtered_data/mimic-iv-demo/2.2/icu/c...
# 5   microbiologyevents.csv  ../basic_filtered_data/mimic-iv-demo/2.2/hosp/...
# 6            labevents.csv  ../basic_filtered_data/mimic-iv-demo/2.2/hosp/...
# 7          inputevents.csv  ../basic_filtered_data/mimic-iv-demo/2.2/icu/i...
# 8           admissions.csv  ../basic_filtered_data/mimic-iv-demo/2.2/hosp/...
# 9           d_labitems.csv  ../basic_filtered_data/mimic-iv-demo/2.2/hosp/...
# 10      datetimeevents.csv  ../basic_filtered_data/mimic-iv-demo/2.2/icu/d...
# 11       prescriptions.csv  ../basic_filtered_data/mimic-iv-demo/2.2/hosp/...
# 12      procedures_icd.csv  ../basic_filtered_data/mimic-iv-demo/2.2/hosp/...
# 13         chartevents.csv  ../basic_filtered_data/mimic-iv-demo/2.2/icu/c...
# 14           transfers.csv  ../basic_filtered_data/mimic-iv-demo/2.2/hosp/...
# 15       diagnoses_icd.csv  ../basic_filtered_data/mimic-iv-demo/2.2/hosp/...
# 16            services.csv  ../basic_filtered_data/mimic-iv-demo/2.2/hosp/...
# 17            drgcodes.csv  ../basic_filtered_data/mimic-iv-demo/2.2/hosp/...
# 18        outputevents.csv  ../basic_filtered_data/mimic-iv-demo/2.2/icu/o...
# 19            patients.csv  ../basic_filtered_data/mimic-iv-demo/2.2/hosp/...
# 20     d_icd_diagnoses.csv  ../basic_filtered_data/mimic-iv-demo/2.2/hosp/...
# 21            icustays.csv  ../basic_filtered_data/mimic-iv-demo/2.2/icu/i...
# 22         inputevents.csv  ../basic_filtered_data/mimic-iv-demo/2.2/icu/i...
# 23    d_icd_procedures.csv  ../basic_filtered_data/mimic-iv-demo/2.2/hosp/...
# 24         inputevents.csv  ../basic_filtered_data/mimic-iv-demo/2.2/icu/i...
#
#     confidence
# 0           86
# 1           49
# 2           72
# 3           90
# 4           56
# 5           95
# 6           95
# 7           90
# 8           95
# 9           95
# 10          95
# 11          95
# 12          95
# 13          95
# 14          95
# 15          95
# 16          90
# 17          90
# 18          95
# 19          90
# 20          95
# 21          90
# 22          83
# 23          95
# 24          80

# %%
list1 = pd.read_csv(mimic_3["PROCEDUREEVENTS_MV"]["filepath"]).columns.to_list()
list2 = pd.read_csv(mimic_4["procedureevents.csv"]["filepath"]).columns.to_list()

# %% [markdown]
# # Column-level cross reference
# After we get the match for each table, we need to do the same for each column in each table.

# %%
def get_matched_columns(df, num_best_match = 3):
    
    for i,row in df.iterrows():
        df_mimic_3 = pd.read_csv(row[1])
        df_mimic_4 = pd.read_csv(row[3])
    
        list1 = df_mimic_3.columns.to_list()
        list2 = df_mimic_4.columns.to_list()
            
        for item1 in list1:
            best_match = None
            best_ratio = 0
            for item2 in list2:
                ratio = fuzz.ratio(item1.lower(), item2.lower())
                if ratio > best_ratio:
                    best_ratio = ratio
                    best_match = item2
            print(f"{item1} -> {best_match} ({best_ratio}%)")
    
    
    
    # lower case all of the data
    # tables_2_lower = [i.lower() for i in tables_2]

    # for i,table_1 in enumerate(tables_1):
    #     matches = process.extract(table_1.lower(),tables_2_lower,limit = num_best_match)
    #     print(f"Best three matches for {table_1}:")
    #     for match in matches:
    #         print(f"{match[0]:<10} Confidence: {match[1]}%")
    #     print()
        # append to output

get_matched_columns(df_table_matches)
# Out:
# Unnamed: 0 -> Unnamed: 0 (100%)
# row_id -> hadm_id (46%)
# subject_id -> subject_id (100%)
# hadm_id -> hadm_id (100%)
# icustay_id -> stay_id (82%)
# starttime -> starttime (100%)
# endtime -> endtime (100%)
# itemid -> itemid (100%)
# value -> value (100%)
# valueuom -> valueuom (100%)
# location -> location (100%)
# locationcategory -> locationcategory (100%)
# storetime -> storetime (100%)
# cgid -> caregiver_id (50%)
# orderid -> orderid (100%)
# linkorderid -> linkorderid (100%)
# ordercategoryname -> ordercategoryname (100%)
# secondaryordercategoryname -> ordercategoryname (79%)
# ordercategorydescription -> ordercategorydescription (100%)
# isopenbag -> isopenbag (100%)
# continueinnextdept -> continueinnextdept (100%)
# cancelreason -> locationcategory (43%)
# statusdescription -> statusdescription (100%)
# comments_editedby -> patientweight (40%)
# comments_canceledby -> continueinnextdept (43%)
# comments_date -> locationcategory (41%)
# Unnamed: 0 -> Unnamed: 0 (100%)
# row_id -> hadm_id (46%)
# subject_id -> subject_id (100%)
# hadm_id -> hadm_id (100%)
# submit_wardid -> subject_id (61%)
# submit_careunit -> subject_id (48%)
# curr_wardid -> caregiver_id (52%)
# curr_careunit -> caregiver_id (40%)
# callout_wardid -> subject_id (42%)
# callout_service -> value (40%)
# request_tele -> caregiver_id (33%)
# request_resp -> caregiver_id (33%)
# request_cdiff -> stay_id (40%)
# request_mrsa -> caregiver_id (33%)
# request_vre -> caregiver_id (35%)
# callout_status -> charttime (35%)
# callout_outcome -> valueuom (52%)
# discharge_wardid -> caregiver_id (57%)
# acknowledge_status -> value (26%)
# createtime -> charttime (74%)
# updatetime -> charttime (63%)
# acknowledgetime -> storetime (50%)
# outcometime -> storetime (60%)
# firstreservationtime -> storetime (55%)
# currentreservationtime -> charttime (45%)
# Unnamed: 0 -> Unnamed: 0 (100%)
# row_id -> code (40%)
# category -> category (100%)
# sectionrange -> short_description (48%)
# sectionheader -> code (47%)
# subsectionrange -> short_description (44%)
# subsectionheader -> short_description (42%)
# codesuffix -> code (57%)
# mincodeinsubsection -> long_description (46%)
# maxcodeinsubsection -> long_description (46%)
# Unnamed: 0 -> Unnamed: 0 (100%)
# row_id -> itemid (33%)
# itemid -> itemid (100%)
# label -> label (100%)
# abbreviation -> abbreviation (100%)
# dbsource -> label (31%)
# linksto -> linksto (100%)
# category -> category (100%)
# unitname -> unitname (100%)
# param_type -> param_type (100%)
# conceptid -> itemid (40%)
# Unnamed: 0 -> Unnamed: 0 (100%)
# row_id -> hadm_id (46%)
# cgid -> caregiver_id (50%)
# label -> value (40%)
# description -> charttime (40%)
# Unnamed: 0 -> Unnamed: 0 (100%)
# row_id -> microevent_id (53%)
# subject_id -> subject_id (100%)
# hadm_id -> hadm_id (100%)
# chartdate -> chartdate (100%)
# charttime -> charttime (100%)
# spec_itemid -> spec_itemid (100%)
# spec_type_desc -> spec_type_desc (100%)
# org_itemid -> org_itemid (100%)
# org_name -> org_name (100%)
# isolate_num -> isolate_num (100%)
# ab_itemid -> ab_itemid (100%)
# ab_name -> ab_name (100%)
# dilution_text -> dilution_text (100%)
# dilution_comparison -> dilution_comparison (100%)
# dilution_value -> dilution_value (100%)
# interpretation -> interpretation (100%)
# Unnamed: 0 -> Unnamed: 0 (100%)
# row_id -> hadm_id (46%)
# subject_id -> subject_id (100%)
# hadm_id -> hadm_id (100%)
# itemid -> itemid (100%)
# charttime -> charttime (100%)
# value -> value (100%)
# valuenum -> valuenum (100%)
# valueuom -> valueuom (100%)
# flag -> flag (100%)
# /var/folders/g9/k6qb06vj6177d3v18ms7g0tw0000gn/T/ipykernel_16048/671652782.py:4: DtypeWarning: Columns (18,21,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_mimic_3 = pd.read_csv(row[1])
# Unnamed: 0 -> Unnamed: 0 (100%)
# row_id -> hadm_id (46%)
# subject_id -> subject_id (100%)
# hadm_id -> hadm_id (100%)
# icustay_id -> stay_id (82%)
# charttime -> starttime (78%)
# itemid -> itemid (100%)
# amount -> amount (100%)
# amountuom -> amountuom (100%)
# rate -> rate (100%)
# rateuom -> rateuom (100%)
# storetime -> storetime (100%)
# cgid -> caregiver_id (50%)
# orderid -> orderid (100%)
# linkorderid -> linkorderid (100%)
# stopped -> storetime (50%)
# newbottle -> starttime (33%)
# originalamount -> originalamount (100%)
# originalamountuom -> originalamount (90%)
# originalroute -> originalrate (88%)
# originalrate -> originalrate (100%)
# originalrateuom -> originalrate (89%)
# originalsite -> originalrate (83%)
# Unnamed: 0 -> Unnamed: 0 (100%)
# row_id -> hadm_id (46%)
# subject_id -> subject_id (100%)
# hadm_id -> hadm_id (100%)
# admittime -> admittime (100%)
# dischtime -> dischtime (100%)
# deathtime -> deathtime (100%)
# admission_type -> admission_type (100%)
# admission_location -> admission_location (100%)
# discharge_location -> discharge_location (100%)
# insurance -> insurance (100%)
# language -> language (100%)
# religion -> discharge_location (46%)
# marital_status -> marital_status (100%)
# ethnicity -> deathtime (44%)
# edregtime -> edregtime (100%)
# edouttime -> edouttime (100%)
# diagnosis -> dischtime (44%)
# hospital_expire_flag -> hospital_expire_flag (100%)
# has_chartevents_data -> discharge_location (47%)
# Unnamed: 0 -> Unnamed: 0 (100%)
# row_id -> fluid (36%)
# itemid -> itemid (100%)
# label -> label (100%)
# fluid -> fluid (100%)
# category -> category (100%)
# loinc_code -> fluid (40%)
# Unnamed: 0 -> Unnamed: 0 (100%)
# row_id -> hadm_id (46%)
# subject_id -> subject_id (100%)
# hadm_id -> hadm_id (100%)
# icustay_id -> stay_id (82%)
# itemid -> itemid (100%)
# charttime -> charttime (100%)
# storetime -> storetime (100%)
# cgid -> caregiver_id (50%)
# value -> value (100%)
# valueuom -> valueuom (100%)
# warning -> warning (100%)
# error -> valueuom (31%)
# resultstatus -> stay_id (32%)
# stopped -> storetime (50%)
# Unnamed: 0 -> Unnamed: 0 (100%)
# row_id -> poe_id (67%)
# subject_id -> subject_id (100%)
# hadm_id -> hadm_id (100%)
# icustay_id -> subject_id (50%)
# startdate -> starttime (78%)
# enddate -> ndc (40%)
# drug_type -> drug_type (100%)
# drug -> drug (100%)
# drug_name_poe -> drug_type (55%)
# drug_name_generic -> drug_type (46%)
# formulary_drug_cd -> formulary_drug_cd (100%)
# gsn -> gsn (100%)
# ndc -> ndc (100%)
# prod_strength -> prod_strength (100%)
# dose_val_rx -> dose_val_rx (100%)
# dose_unit_rx -> dose_unit_rx (100%)
# form_val_disp -> form_val_disp (100%)
# form_unit_disp -> form_unit_disp (100%)
# route -> route (100%)
# Unnamed: 0 -> Unnamed: 0 (100%)
# row_id -> hadm_id (46%)
# subject_id -> subject_id (100%)
# hadm_id -> hadm_id (100%)
# seq_num -> seq_num (100%)
# icd9_code -> icd_code (94%)
# /var/folders/g9/k6qb06vj6177d3v18ms7g0tw0000gn/T/ipykernel_16048/671652782.py:4: DtypeWarning: Columns (9,11,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_mimic_3 = pd.read_csv(row[1])
# Unnamed: 0 -> Unnamed: 0 (100%)
# row_id -> hadm_id (46%)
# subject_id -> subject_id (100%)
# hadm_id -> hadm_id (100%)
# icustay_id -> stay_id (82%)
# itemid -> itemid (100%)
# charttime -> charttime (100%)
# storetime -> storetime (100%)
# cgid -> caregiver_id (50%)
# value -> value (100%)
# valuenum -> valuenum (100%)
# valueuom -> valueuom (100%)
# warning -> warning (100%)
# error -> valueuom (31%)
# resultstatus -> stay_id (32%)
# stopped -> storetime (50%)
# Unnamed: 0 -> Unnamed: 0 (100%)
# row_id -> transfer_id (47%)
# subject_id -> subject_id (100%)
# hadm_id -> hadm_id (100%)
# icustay_id -> subject_id (50%)
# dbsource -> outtime (40%)
# eventtype -> eventtype (100%)
# prev_careunit -> careunit (76%)
# curr_careunit -> careunit (76%)
# prev_wardid -> transfer_id (45%)
# curr_wardid -> transfer_id (45%)
# intime -> intime (100%)
# outtime -> outtime (100%)
# los -> outtime (20%)
# Unnamed: 0 -> Unnamed: 0 (100%)
# row_id -> hadm_id (46%)
# subject_id -> subject_id (100%)
# hadm_id -> hadm_id (100%)
# seq_num -> seq_num (100%)
# icd9_code -> icd_code (94%)
# Unnamed: 0 -> Unnamed: 0 (100%)
# row_id -> hadm_id (46%)
# subject_id -> subject_id (100%)
# hadm_id -> hadm_id (100%)
# transfertime -> transfertime (100%)
# prev_service -> prev_service (100%)
# curr_service -> curr_service (100%)
# Unnamed: 0 -> Unnamed: 0 (100%)
# row_id -> hadm_id (46%)
# subject_id -> subject_id (100%)
# hadm_id -> hadm_id (100%)
# drg_type -> drg_type (100%)
# drg_code -> drg_code (100%)
# description -> description (100%)
# drg_severity -> drg_severity (100%)
# drg_mortality -> drg_mortality (100%)
# Unnamed: 0 -> Unnamed: 0 (100%)
# row_id -> hadm_id (46%)
# subject_id -> subject_id (100%)
# hadm_id -> hadm_id (100%)
# icustay_id -> stay_id (82%)
# charttime -> charttime (100%)
# itemid -> itemid (100%)
# value -> value (100%)
# valueuom -> valueuom (100%)
# storetime -> storetime (100%)
# cgid -> caregiver_id (50%)
# stopped -> storetime (50%)
# newbottle -> charttime (33%)
# iserror -> storetime (38%)
# Unnamed: 0 -> Unnamed: 0 (100%)
# row_id -> dod (44%)
# subject_id -> subject_id (100%)
# gender -> gender (100%)
# dob -> dod (67%)
# dod -> dod (100%)
# dod_hosp -> dod (55%)
# dod_ssn -> dod (60%)
# expire_flag -> anchor_age (38%)
# Unnamed: 0 -> Unnamed: 0 (100%)
# row_id -> long_title (38%)
# icd9_code -> icd_code (94%)
# short_title -> long_title (67%)
# long_title -> long_title (100%)
# Unnamed: 0 -> Unnamed: 0 (100%)
# row_id -> hadm_id (46%)
# subject_id -> subject_id (100%)
# hadm_id -> hadm_id (100%)
# icustay_id -> stay_id (82%)
# dbsource -> outtime (40%)
# first_careunit -> first_careunit (100%)
# last_careunit -> last_careunit (100%)
# first_wardid -> first_careunit (69%)
# last_wardid -> last_careunit (67%)
# intime -> intime (100%)
# outtime -> outtime (100%)
# los -> los (100%)
# Unnamed: 0 -> Unnamed: 0 (100%)
# row_id -> hadm_id (46%)
# subject_id -> subject_id (100%)
# hadm_id -> hadm_id (100%)
# icustay_id -> stay_id (82%)
# starttime -> starttime (100%)
# endtime -> endtime (100%)
# itemid -> itemid (100%)
# amount -> amount (100%)
# amountuom -> amountuom (100%)
# rate -> rate (100%)
# rateuom -> rateuom (100%)
# storetime -> storetime (100%)
# cgid -> caregiver_id (50%)
# orderid -> orderid (100%)
# linkorderid -> linkorderid (100%)
# ordercategoryname -> ordercategoryname (100%)
# secondaryordercategoryname -> secondaryordercategoryname (100%)
# ordercomponenttypedescription -> ordercomponenttypedescription (100%)
# ordercategorydescription -> ordercategorydescription (100%)
# patientweight -> patientweight (100%)
# totalamount -> totalamount (100%)
# totalamountuom -> totalamountuom (100%)
# isopenbag -> isopenbag (100%)
# continueinnextdept -> continueinnextdept (100%)
# cancelreason -> caregiver_id (33%)
# statusdescription -> statusdescription (100%)
# comments_editedby -> ordercomponenttypedescription (43%)
# comments_canceledby -> continueinnextdept (43%)
# comments_date -> originalrate (40%)
# originalamount -> originalamount (100%)
# originalrate -> originalrate (100%)
# Unnamed: 0 -> Unnamed: 0 (100%)
# row_id -> long_title (38%)
# icd9_code -> icd_code (94%)
# short_title -> long_title (67%)
# long_title -> long_title (100%)
# Unnamed: 0 -> Unnamed: 0 (100%)
# row_id -> hadm_id (46%)
# subject_id -> subject_id (100%)
# hadm_id -> hadm_id (100%)
# costcenter -> storetime (53%)
# chartdate -> rate (62%)
# cpt_cd -> subject_id (50%)
# cpt_number -> endtime (35%)
# cpt_suffix -> subject_id (40%)
# ticket_id_seq -> subject_id (43%)
# sectionheader -> subject_id (52%)
# subsectionheader -> subject_id (62%)
# description -> statusdescription (79%)

# %%
df_table_matches
# Out:
#          table_mimic_3                                    filepath_mimic3
# 0   PROCEDUREEVENTS_MV  ../basic_filtered_data/mimic-iii-demo/PROCEDUR...  \
# 1              CALLOUT  ../basic_filtered_data/mimic-iii-demo/CALLOUT.csv
# 2                D_CPT    ../basic_filtered_data/mimic-iii-demo/D_CPT.csv
# 3              D_ITEMS  ../basic_filtered_data/mimic-iii-demo/D_ITEMS.csv
# 4           CAREGIVERS  ../basic_filtered_data/mimic-iii-demo/CAREGIVE...
# 5   MICROBIOLOGYEVENTS  ../basic_filtered_data/mimic-iii-demo/MICROBIO...
# 6            LABEVENTS  ../basic_filtered_data/mimic-iii-demo/LABEVENT...
# 7       INPUTEVENTS_CV  ../basic_filtered_data/mimic-iii-demo/INPUTEVE...
# 8           ADMISSIONS  ../basic_filtered_data/mimic-iii-demo/ADMISSIO...
# 9           D_LABITEMS  ../basic_filtered_data/mimic-iii-demo/D_LABITE...
# 10      DATETIMEEVENTS  ../basic_filtered_data/mimic-iii-demo/DATETIME...
# 11       PRESCRIPTIONS  ../basic_filtered_data/mimic-iii-demo/PRESCRIP...
# 12      PROCEDURES_ICD  ../basic_filtered_data/mimic-iii-demo/PROCEDUR...
# 13         CHARTEVENTS  ../basic_filtered_data/mimic-iii-demo/CHARTEVE...
# 14           TRANSFERS  ../basic_filtered_data/mimic-iii-demo/TRANSFER...
# 15       DIAGNOSES_ICD  ../basic_filtered_data/mimic-iii-demo/DIAGNOSE...
# 16            SERVICES  ../basic_filtered_data/mimic-iii-demo/SERVICES...
# 17            DRGCODES  ../basic_filtered_data/mimic-iii-demo/DRGCODES...
# 18        OUTPUTEVENTS  ../basic_filtered_data/mimic-iii-demo/OUTPUTEV...
# 19            PATIENTS  ../basic_filtered_data/mimic-iii-demo/PATIENTS...
# 20     D_ICD_DIAGNOSES  ../basic_filtered_data/mimic-iii-demo/D_ICD_DI...
# 21            ICUSTAYS  ../basic_filtered_data/mimic-iii-demo/ICUSTAYS...
# 22      INPUTEVENTS_MV  ../basic_filtered_data/mimic-iii-demo/INPUTEVE...
# 23    D_ICD_PROCEDURES  ../basic_filtered_data/mimic-iii-demo/D_ICD_PR...
# 24           CPTEVENTS  ../basic_filtered_data/mimic-iii-demo/CPTEVENT...
#
#              table_mimic_4                                    filepath_mimic4
# 0      procedureevents.csv  ../basic_filtered_data/mimic-iv-demo/2.2/icu/p...  \
# 1         outputevents.csv  ../basic_filtered_data/mimic-iv-demo/2.2/icu/o...
# 2              d_hcpcs.csv  ../basic_filtered_data/mimic-iv-demo/2.2/hosp/...
# 3              d_items.csv  ../basic_filtered_data/mimic-iv-demo/2.2/icu/d...
# 4          chartevents.csv  ../basic_filtered_data/mimic-iv-demo/2.2/icu/c...
# 5   microbiologyevents.csv  ../basic_filtered_data/mimic-iv-demo/2.2/hosp/...
# 6            labevents.csv  ../basic_filtered_data/mimic-iv-demo/2.2/hosp/...
# 7          inputevents.csv  ../basic_filtered_data/mimic-iv-demo/2.2/icu/i...
# 8           admissions.csv  ../basic_filtered_data/mimic-iv-demo/2.2/hosp/...
# 9           d_labitems.csv  ../basic_filtered_data/mimic-iv-demo/2.2/hosp/...
# 10      datetimeevents.csv  ../basic_filtered_data/mimic-iv-demo/2.2/icu/d...
# 11       prescriptions.csv  ../basic_filtered_data/mimic-iv-demo/2.2/hosp/...
# 12      procedures_icd.csv  ../basic_filtered_data/mimic-iv-demo/2.2/hosp/...
# 13         chartevents.csv  ../basic_filtered_data/mimic-iv-demo/2.2/icu/c...
# 14           transfers.csv  ../basic_filtered_data/mimic-iv-demo/2.2/hosp/...
# 15       diagnoses_icd.csv  ../basic_filtered_data/mimic-iv-demo/2.2/hosp/...
# 16            services.csv  ../basic_filtered_data/mimic-iv-demo/2.2/hosp/...
# 17            drgcodes.csv  ../basic_filtered_data/mimic-iv-demo/2.2/hosp/...
# 18        outputevents.csv  ../basic_filtered_data/mimic-iv-demo/2.2/icu/o...
# 19            patients.csv  ../basic_filtered_data/mimic-iv-demo/2.2/hosp/...
# 20     d_icd_diagnoses.csv  ../basic_filtered_data/mimic-iv-demo/2.2/hosp/...
# 21            icustays.csv  ../basic_filtered_data/mimic-iv-demo/2.2/icu/i...
# 22         inputevents.csv  ../basic_filtered_data/mimic-iv-demo/2.2/icu/i...
# 23    d_icd_procedures.csv  ../basic_filtered_data/mimic-iv-demo/2.2/hosp/...
# 24         inputevents.csv  ../basic_filtered_data/mimic-iv-demo/2.2/icu/i...
#
#     confidence
# 0           86
# 1           49
# 2           72
# 3           90
# 4           56
# 5           95
# 6           95
# 7           90
# 8           95
# 9           95
# 10          95
# 11          95
# 12          95
# 13          95
# 14          95
# 15          95
# 16          90
# 17          90
# 18          95
# 19          90
# 20          95
# 21          90
# 22          83
# 23          95
# 24          80

# %% [markdown]
# Now we need to find out a way to perform the column match.
# 1. read in a table in mimic 3 and in mimic 4
# 2. calculate the score
# 3. output into the following format
#
# |{filename_3}|{filename_4}|column_mimic3|column_mimic4|datatype|score|required|
# |----|---|---|---|---|---|---|
# |-|-|-|-|-|-|-|

# %%
def find_best_matches(list_a, list_b):
    """
    input two list, output fuzzy comparison between 

    :param _type_ list_a: _description_
    :param _type_ list_b: _description_
    :return _type_: _description_
    """
    # Initialize empty lists for the output
    a_matches = []
    b_matches = []
    scores = []

    # Iterate through each item in list A
    for a in list_a:
        # Use fuzzywuzzy to find the best match for the current item in list B, comparing lowercase strings
        matches = process.extract(a.lower(), [b.lower() for b in list_b], limit=1)
        best_match = matches[0][0]
        score = matches[0][1]

        # Add the current item in list A and its best match and score to the output lists
        a_matches.append(a)
        b_matches.append(best_match)
        scores.append(score)

    # Create a dataframe from the output lists
    # df = pd.DataFrame({'List A': a_matches, 'List B Match': b_matches, 'Match Score': scores})
    return a_matches, b_matches, scores

# %%
mimic_3
# Out:
# {'PROCEDUREEVENTS_MV': {'Unnamed: 0': 'int',
#   'row_id': 'int',
#   'subject_id': 'int',
#   'hadm_id': 'int',
#   'icustay_id': 'int',
#   'starttime': 'datetime',
#   'endtime': 'datetime',
#   'itemid': 'datetime',
#   'value': 'int',
#   'valueuom': 'string',
#   'location': 'string',
#   'locationcategory': 'string',
#   'storetime': 'datetime',
#   'cgid': 'int',
#   'orderid': 'int',
#   'linkorderid': 'int',
#   'ordercategoryname': 'string',
#   'secondaryordercategoryname': None,
#   'ordercategorydescription': 'string',
#   'isopenbag': 'int',
#   'continueinnextdept': 'int',
#   'cancelreason': 'int',
#   'statusdescription': 'string',
#   'comments_editedby': 'string',
#   'comments_canceledby': 'string',
#   'comments_date': 'datetime',
#   'filepath': '../basic_filtered_data/mimic-iii-demo/PROCEDUREEVENTS_MV.csv'},
#  'CALLOUT': {'Unnamed: 0': 'int',
#   'row_id': 'int',
#   'subject_id': 'int',
#   'hadm_id': 'int',
#   'submit_wardid': 'int',
#   'submit_careunit': 'string',
#   'curr_wardid': 'int',
#   'curr_careunit': 'string',
#   'callout_wardid': 'int',
#   'callout_service': 'string',
#   'request_tele': 'int',
#   'request_resp': 'int',
#   'request_cdiff': 'int',
#   'request_mrsa': 'int',
#   'request_vre': 'int',
#   'callout_status': 'string',
#   'callout_outcome': 'string',
#   'discharge_wardid': 'int',
#   'acknowledge_status': 'string',
#   'createtime': 'datetime',
#   'updatetime': 'datetime',
#   'acknowledgetime': 'datetime',
#   'outcometime': 'datetime',
#   'firstreservationtime': 'datetime',
#   'currentreservationtime': 'datetime',
#   'filepath': '../basic_filtered_data/mimic-iii-demo/CALLOUT.csv'},
#  'D_CPT': {'Unnamed: 0': 'int',
#   'row_id': 'int',
#   'category': 'int',
#   'sectionrange': 'string',
#   'sectionheader': 'string',
#   'subsectionrange': 'string',
#   'subsectionheader': 'string',
#   'codesuffix': 'string',
#   'mincodeinsubsection': 'int',
#   'maxcodeinsubsection': 'int',
#   'filepath': '../basic_filtered_data/mimic-iii-demo/D_CPT.csv'},
#  'D_ITEMS': {'Unnamed: 0': 'int',
#   'row_id': 'int',
#   'itemid': 'int',
#   'label': 'string',
#   'abbreviation': 'string',
#   'dbsource': 'string',
#   'linksto': 'string',
#   'category': 'string',
#   'unitname': 'string',
#   'param_type': 'string',
#   'conceptid': None,
#   'filepath': '../basic_filtered_data/mimic-iii-demo/D_ITEMS.csv'},
#  'CAREGIVERS': {'Unnamed: 0': 'int',
#   'row_id': 'int',
#   'cgid': 'int',
#   'label': 'string',
#   'description': 'string',
#   'filepath': '../basic_filtered_data/mimic-iii-demo/CAREGIVERS.csv'},
#  'MICROBIOLOGYEVENTS': {'Unnamed: 0': 'int',
#   'row_id': 'datetime',
#   'subject_id': 'int',
#   'hadm_id': 'int',
#   'chartdate': 'datetime',
#   'charttime': 'datetime',
#   'spec_itemid': 'int',
#   'spec_type_desc': 'string',
#   'org_itemid': 'int',
#   'org_name': 'string',
#   'isolate_num': 'int',
#   'ab_itemid': 'int',
#   'ab_name': 'string',
#   'dilution_text': 'string',
#   'dilution_comparison': 'string',
#   'dilution_value': 'int',
#   'interpretation': 'string',
#   'filepath': '../basic_filtered_data/mimic-iii-demo/MICROBIOLOGYEVENTS.csv'},
#  'LABEVENTS': {'Unnamed: 0': 'int',
#   'row_id': 'int',
#   'subject_id': 'int',
#   'hadm_id': 'int',
#   'itemid': 'int',
#   'charttime': 'datetime',
#   'value': 'string',
#   'valuenum': 'float',
#   'valueuom': 'string',
#   'flag': 'string',
#   'filepath': '../basic_filtered_data/mimic-iii-demo/LABEVENTS.csv'},
#  'INPUTEVENTS_CV': {'Unnamed: 0': 'int',
#   'row_id': 'int',
#   'subject_id': 'int',
#   'hadm_id': 'int',
#   'icustay_id': 'int',
#   'charttime': 'datetime',
#   'itemid': 'int',
#   'amount': 'float',
#   'amountuom': 'string',
#   'rate': 'float',
#   'rateuom': 'string',
#   'storetime': 'datetime',
#   'cgid': 'int',
#   'orderid': 'int',
#   'linkorderid': 'int',
#   'stopped': 'string',
#   'newbottle': 'int',
#   'originalamount': 'float',
#   'originalamountuom': 'string',
#   'originalroute': 'string',
#   'originalrate': 'float',
#   'originalrateuom': 'string',
#   'originalsite': 'string',
#   'filepath': '../basic_filtered_data/mimic-iii-demo/INPUTEVENTS_CV.csv'},
#  'ADMISSIONS': {'Unnamed: 0': 'int',
#   'row_id': 'int',
#   'subject_id': 'int',
#   'hadm_id': 'int',
#   'admittime': 'datetime',
#   'dischtime': 'datetime',
#   'deathtime': 'datetime',
#   'admission_type': 'string',
#   'admission_location': 'string',
#   'discharge_location': 'string',
#   'insurance': 'string',
#   'language': 'string',
#   'religion': 'string',
#   'marital_status': 'string',
#   'ethnicity': 'string',
#   'edregtime': 'datetime',
#   'edouttime': 'datetime',
#   'diagnosis': 'string',
#   'hospital_expire_flag': 'int',
#   'has_chartevents_data': 'int',
#   'filepath': '../basic_filtered_data/mimic-iii-demo/ADMISSIONS.csv'},
#  'D_LABITEMS': {'Unnamed: 0': 'int',
#   'row_id': 'int',
#   'itemid': 'int',
#   'label': 'string',
#   'fluid': 'string',
#   'category': 'string',
#   'loinc_code': 'string',
#   'filepath': '../basic_filtered_data/mimic-iii-demo/D_LABITEMS.csv'},
#  'DATETIMEEVENTS': {'Unnamed: 0': 'int',
#   'row_id': 'int',
#   'subject_id': 'int',
#   'hadm_id': 'int',
#   'icustay_id': 'int',
#   'itemid': 'int',
#   'charttime': 'datetime',
#   'storetime': 'datetime',
#   'cgid': 'int',
#   'value': 'datetime',
#   'valueuom': 'string',
#   'warning': 'int',
#   'error': 'int',
#   'resultstatus': None,
#   'stopped': 'string',
#   'filepath': '../basic_filtered_data/mimic-iii-demo/DATETIMEEVENTS.csv'},
#  'PRESCRIPTIONS': {'Unnamed: 0': 'int',
#   'row_id': 'int',
#   'subject_id': 'int',
#   'hadm_id': 'int',
#   'icustay_id': 'int',
#   'startdate': 'datetime',
#   'enddate': 'datetime',
#   'drug_type': 'string',
#   'drug': 'string',
#   'drug_name_poe': 'string',
#   'drug_name_generic': 'string',
#   'formulary_drug_cd': 'string',
#   'gsn': 'int',
#   'ndc': 'int',
#   'prod_strength': 'string',
#   'dose_val_rx': 'string',
#   'dose_unit_rx': 'string',
#   'form_val_disp': 'string',
#   'form_unit_disp': 'string',
#   'route': 'string',
#   'filepath': '../basic_filtered_data/mimic-iii-demo/PRESCRIPTIONS.csv'},
#  'PROCEDURES_ICD': {'Unnamed: 0': 'int',
#   'row_id': 'int',
#   'subject_id': 'int',
#   'hadm_id': 'int',
#   'seq_num': 'int',
#   'icd9_code': 'int',
#   'filepath': '../basic_filtered_data/mimic-iii-demo/PROCEDURES_ICD.csv'},
#  'CHARTEVENTS': {'Unnamed: 0': 'int',
#   'row_id': 'int',
#   'subject_id': 'int',
#   'hadm_id': 'int',
#   'icustay_id': 'int',
#   'itemid': 'int',
#   'charttime': 'datetime',
#   'storetime': 'datetime',
#   'cgid': 'int',
#   'value': 'string',
#   'valuenum': 'float',
#   'valueuom': 'string',
#   'warning': 'int',
#   'error': 'int',
#   'resultstatus': 'string',
#   'stopped': 'string',
#   'filepath': '../basic_filtered_data/mimic-iii-demo/CHARTEVENTS.csv'},
#  'TRANSFERS': {'Unnamed: 0': 'int',
#   'row_id': 'int',
#   'subject_id': 'int',
#   'hadm_id': 'int',
#   'icustay_id': 'int',
#   'dbsource': 'string',
#   'eventtype': 'string',
#   'prev_careunit': 'string',
#   'curr_careunit': 'string',
#   'prev_wardid': 'int',
#   'curr_wardid': 'int',
#   'intime': 'datetime',
#   'outtime': 'datetime',
#   'los': 'float',
#   'filepath': '../basic_filtered_data/mimic-iii-demo/TRANSFERS.csv'},
#  'DIAGNOSES_ICD': {'Unnamed: 0': 'int',
#   'row_id': 'int',
#   'subject_id': 'int',
#   'hadm_id': 'int',
#   'seq_num': 'int',
#   'icd9_code': 'string',
#   'filepath': '../basic_filtered_data/mimic-iii-demo/DIAGNOSES_ICD.csv'},
#  'SERVICES': {'Unnamed: 0': 'int',
#   'row_id': 'int',
#   'subject_id': 'int',
#   'hadm_id': 'int',
#   'transfertime': 'datetime',
#   'prev_service': 'string',
#   'curr_service': 'string',
#   'filepath': '../basic_filtered_data/mimic-iii-demo/SERVICES.csv'},
#  'DRGCODES': {'Unnamed: 0': 'int',
#   'row_id': 'int',
#   'subject_id': 'int',
#   'hadm_id': 'int',
#   'drg_type': 'string',
#   'drg_code': 'int',
#   'description': 'string',
#   'drg_severity': 'int',
#   'drg_mortality': 'int',
#   'filepath': '../basic_filtered_data/mimic-iii-demo/DRGCODES.csv'},
#  'OUTPUTEVENTS': {'Unnamed: 0': 'int',
#   'row_id': 'int',
#   'subject_id': 'int',
#   'hadm_id': 'int',
#   'icustay_id': 'int',
#   'charttime': 'datetime',
#   'itemid': 'int',
#   'value': 'int',
#   'valueuom': 'string',
#   'storetime': 'datetime',
#   'cgid': 'int',
#   'stopped': None,
#   'newbottle': None,
#   'iserror': None,
#   'filepath': '../basic_filtered_data/mimic-iii-demo/OUTPUTEVENTS.csv'},
#  'PATIENTS': {'Unnamed: 0': 'int',
#   'row_id': 'int',
#   'subject_id': 'int',
#   'gender': 'string',
#   'dob': 'datetime',
#   'dod': 'datetime',
#   'dod_hosp': 'datetime',
#   'dod_ssn': 'datetime',
#   'expire_flag': 'int',
#   'filepath': '../basic_filtered_data/mimic-iii-demo/PATIENTS.csv'},
#  'D_ICD_DIAGNOSES': {'Unnamed: 0': 'int',
#   'row_id': 'int',
#   'icd9_code': 'string',
#   'short_title': 'string',
#   'long_title': 'string',
#   'filepath': '../basic_filtered_data/mimic-iii-demo/D_ICD_DIAGNOSES.csv'},
#  'ICUSTAYS': {'Unnamed: 0': 'int',
#   'row_id': 'int',
#   'subject_id': 'int',
#   'hadm_id': 'int',
#   'icustay_id': 'int',
#   'dbsource': 'string',
#   'first_careunit': 'string',
#   'last_careunit': 'string',
#   'first_wardid': 'int',
#   'last_wardid': 'int',
#   'intime': 'datetime',
#   'outtime': 'datetime',
#   'los': 'float',
#   'filepath': '../basic_filtered_data/mimic-iii-demo/ICUSTAYS.csv'},
#  'INPUTEVENTS_MV': {'Unnamed: 0': 'int',
#   'row_id': 'int',
#   'subject_id': 'int',
#   'hadm_id': 'int',
#   'icustay_id': 'int',
#   'starttime': 'datetime',
#   'endtime': 'datetime',
#   'itemid': 'datetime',
#   'amount': 'float',
#   'amountuom': 'string',
#   'rate': 'float',
#   'rateuom': 'string',
#   'storetime': 'datetime',
#   'cgid': 'int',
#   'orderid': 'int',
#   'linkorderid': 'int',
#   'ordercategoryname': 'string',
#   'secondaryordercategoryname': 'string',
#   'ordercomponenttypedescription': 'string',
#   'ordercategorydescription': 'string',
#   'patientweight': 'float',
#   'totalamount': 'float',
#   'totalamountuom': 'string',
#   'isopenbag': 'int',
#   'continueinnextdept': 'int',
#   'cancelreason': 'int',
#   'statusdescription': 'string',
#   'comments_editedby': 'string',
#   'comments_canceledby': 'string',
#   'comments_date': 'datetime',
#   'originalamount': 'float',
#   'originalrate': 'float',
#   'filepath': '../basic_filtered_data/mimic-iii-demo/INPUTEVENTS_MV.csv'},
#  'D_ICD_PROCEDURES': {'Unnamed: 0': 'int',
#   'row_id': 'int',
#   'icd9_code': 'int',
#   'short_title': 'string',
#   'long_title': 'string',
#   'filepath': '../basic_filtered_data/mimic-iii-demo/D_ICD_PROCEDURES.csv'},
#  'CPTEVENTS': {'Unnamed: 0': 'int',
#   'row_id': 'int',
#   'subject_id': 'int',
#   'hadm_id': 'int',
#   'costcenter': 'string',
#   'chartdate': 'datetime',
#   'cpt_cd': 'int',
#   'cpt_number': 'int',
#   'cpt_suffix': None,
#   'ticket_id_seq': 'int',
#   'sectionheader': 'string',
#   'subsectionheader': 'string',
#   'description': 'string',
#   'filepath': '../basic_filtered_data/mimic-iii-demo/CPTEVENTS.csv'}}

# %%
def get_columns(tables_mimic3,tables_mimic4,meta_mimic3,meta_mimic4,threshold = 80):

    table_match = dict(zip(tables_mimic3,tables_mimic4))
    
    df_result = pd.DataFrame()
    
    # unpack the table name in mimic 3 and 4 for comparison
    for table_mimic3,table_mimic4 in table_match.items():
        # print(list(meta_mimic3[table_mimic3].keys()))
        columns_mimic3,columns_mimic4,scores = find_best_matches(list(meta_mimic3[table_mimic3].keys()),
                                  list(meta_mimic4[table_mimic4].keys()))
        
        # find the datatype from mimic3
        datatype_m3 = [meta_mimic3[table_mimic3][column] for column in columns_mimic3]
        
        df = pd.DataFrame(
            {
                "mimic3" : [table_mimic3 for i in range(len(columns_mimic3))],
                "mimic4" : [table_mimic4 for i in range(len(columns_mimic4))],
                "column_mimic3" : columns_mimic3,
                "column_mimic4_candidate_1" : columns_mimic4,
                "candidate_1_scores" : scores,
                "dtype_mimic3": datatype_m3,
                "mimic3_filepath": [meta_mimic3[table_mimic3]["filepath"] for i in range(len(columns_mimic3))],
                "mimic4_filepath": [meta_mimic4[table_mimic4]["filepath"] for i in range(len(columns_mimic4))],   
            }
        )
        
        
        
        df_result = pd.concat([df_result,df],axis = 0)
    return df_result

df = get_columns(df_table_matches["table_mimic_3"].to_list(),
            df_table_matches["table_mimic_4"].to_list(),
            mimic_3,
            mimic_4)
df.head(30)
# Out:
#                 mimic3               mimic4               column_mimic3
# 0   PROCEDUREEVENTS_MV  procedureevents.csv                  Unnamed: 0  \
# 1   PROCEDUREEVENTS_MV  procedureevents.csv                      row_id
# 2   PROCEDUREEVENTS_MV  procedureevents.csv                  subject_id
# 3   PROCEDUREEVENTS_MV  procedureevents.csv                     hadm_id
# 4   PROCEDUREEVENTS_MV  procedureevents.csv                  icustay_id
# 5   PROCEDUREEVENTS_MV  procedureevents.csv                   starttime
# 6   PROCEDUREEVENTS_MV  procedureevents.csv                     endtime
# 7   PROCEDUREEVENTS_MV  procedureevents.csv                      itemid
# 8   PROCEDUREEVENTS_MV  procedureevents.csv                       value
# 9   PROCEDUREEVENTS_MV  procedureevents.csv                    valueuom
# 10  PROCEDUREEVENTS_MV  procedureevents.csv                    location
# 11  PROCEDUREEVENTS_MV  procedureevents.csv            locationcategory
# 12  PROCEDUREEVENTS_MV  procedureevents.csv                   storetime
# 13  PROCEDUREEVENTS_MV  procedureevents.csv                        cgid
# 14  PROCEDUREEVENTS_MV  procedureevents.csv                     orderid
# 15  PROCEDUREEVENTS_MV  procedureevents.csv                 linkorderid
# 16  PROCEDUREEVENTS_MV  procedureevents.csv           ordercategoryname
# 17  PROCEDUREEVENTS_MV  procedureevents.csv  secondaryordercategoryname
# 18  PROCEDUREEVENTS_MV  procedureevents.csv    ordercategorydescription
# 19  PROCEDUREEVENTS_MV  procedureevents.csv                   isopenbag
# 20  PROCEDUREEVENTS_MV  procedureevents.csv          continueinnextdept
# 21  PROCEDUREEVENTS_MV  procedureevents.csv                cancelreason
# 22  PROCEDUREEVENTS_MV  procedureevents.csv           statusdescription
# 23  PROCEDUREEVENTS_MV  procedureevents.csv           comments_editedby
# 24  PROCEDUREEVENTS_MV  procedureevents.csv         comments_canceledby
# 25  PROCEDUREEVENTS_MV  procedureevents.csv               comments_date
# 26  PROCEDUREEVENTS_MV  procedureevents.csv                    filepath
# 0              CALLOUT     outputevents.csv                  Unnamed: 0
# 1              CALLOUT     outputevents.csv                      row_id
# 2              CALLOUT     outputevents.csv                  subject_id
#
#    column_mimic4_candidate_1  candidate_1_scores
# 0                 unnamed: 0                 100  \
# 1               caregiver_id                  60
# 2                 subject_id                 100
# 3                    hadm_id                 100
# 4                    stay_id                  82
# 5                  starttime                 100
# 6                    endtime                 100
# 7                     itemid                 100
# 8                      value                 100
# 9                   valueuom                 100
# 10                  location                 100
# 11          locationcategory                 100
# 12                 storetime                 100
# 13              caregiver_id                  50
# 14                   orderid                 100
# 15               linkorderid                 100
# 16         ordercategoryname                 100
# 17         ordercategoryname                  90
# 18  ordercategorydescription                 100
# 19                 isopenbag                 100
# 20        continueinnextdept                 100
# 21                  location                  45
# 22         statusdescription                 100
# 23                    itemid                  60
# 24        continueinnextdept                  43
# 25          locationcategory                  41
# 26                  filepath                 100
# 0                 unnamed: 0                 100
# 1               caregiver_id                  60
# 2                 subject_id                 100
#
#                                          dtype_mimic3
# 0                                                 int  \
# 1                                                 int
# 2                                                 int
# 3                                                 int
# 4                                                 int
# 5                                            datetime
# 6                                            datetime
# 7                                            datetime
# 8                                                 int
# 9                                              string
# 10                                             string
# 11                                             string
# 12                                           datetime
# 13                                                int
# 14                                                int
# 15                                                int
# 16                                             string
# 17                                               None
# 18                                             string
# 19                                                int
# 20                                                int
# 21                                                int
# 22                                             string
# 23                                             string
# 24                                             string
# 25                                           datetime
# 26  ../basic_filtered_data/mimic-iii-demo/PROCEDUR...
# 0                                                 int
# 1                                                 int
# 2                                                 int
#
#                                       mimic3_filepath
# 0   ../basic_filtered_data/mimic-iii-demo/PROCEDUR...  \
# 1   ../basic_filtered_data/mimic-iii-demo/PROCEDUR...
# 2   ../basic_filtered_data/mimic-iii-demo/PROCEDUR...
# 3   ../basic_filtered_data/mimic-iii-demo/PROCEDUR...
# 4   ../basic_filtered_data/mimic-iii-demo/PROCEDUR...
# 5   ../basic_filtered_data/mimic-iii-demo/PROCEDUR...
# 6   ../basic_filtered_data/mimic-iii-demo/PROCEDUR...
# 7   ../basic_filtered_data/mimic-iii-demo/PROCEDUR...
# 8   ../basic_filtered_data/mimic-iii-demo/PROCEDUR...
# 9   ../basic_filtered_data/mimic-iii-demo/PROCEDUR...
# 10  ../basic_filtered_data/mimic-iii-demo/PROCEDUR...
# 11  ../basic_filtered_data/mimic-iii-demo/PROCEDUR...
# 12  ../basic_filtered_data/mimic-iii-demo/PROCEDUR...
# 13  ../basic_filtered_data/mimic-iii-demo/PROCEDUR...
# 14  ../basic_filtered_data/mimic-iii-demo/PROCEDUR...
# 15  ../basic_filtered_data/mimic-iii-demo/PROCEDUR...
# 16  ../basic_filtered_data/mimic-iii-demo/PROCEDUR...
# 17  ../basic_filtered_data/mimic-iii-demo/PROCEDUR...
# 18  ../basic_filtered_data/mimic-iii-demo/PROCEDUR...
# 19  ../basic_filtered_data/mimic-iii-demo/PROCEDUR...
# 20  ../basic_filtered_data/mimic-iii-demo/PROCEDUR...
# 21  ../basic_filtered_data/mimic-iii-demo/PROCEDUR...
# 22  ../basic_filtered_data/mimic-iii-demo/PROCEDUR...
# 23  ../basic_filtered_data/mimic-iii-demo/PROCEDUR...
# 24  ../basic_filtered_data/mimic-iii-demo/PROCEDUR...
# 25  ../basic_filtered_data/mimic-iii-demo/PROCEDUR...
# 26  ../basic_filtered_data/mimic-iii-demo/PROCEDUR...
# 0   ../basic_filtered_data/mimic-iii-demo/CALLOUT.csv
# 1   ../basic_filtered_data/mimic-iii-demo/CALLOUT.csv
# 2   ../basic_filtered_data/mimic-iii-demo/CALLOUT.csv
#
#                                       mimic4_filepath
# 0   ../basic_filtered_data/mimic-iv-demo/2.2/icu/p...
# 1   ../basic_filtered_data/mimic-iv-demo/2.2/icu/p...
# 2   ../basic_filtered_data/mimic-iv-demo/2.2/icu/p...
# 3   ../basic_filtered_data/mimic-iv-demo/2.2/icu/p...
# 4   ../basic_filtered_data/mimic-iv-demo/2.2/icu/p...
# 5   ../basic_filtered_data/mimic-iv-demo/2.2/icu/p...
# 6   ../basic_filtered_data/mimic-iv-demo/2.2/icu/p...
# 7   ../basic_filtered_data/mimic-iv-demo/2.2/icu/p...
# 8   ../basic_filtered_data/mimic-iv-demo/2.2/icu/p...
# 9   ../basic_filtered_data/mimic-iv-demo/2.2/icu/p...
# 10  ../basic_filtered_data/mimic-iv-demo/2.2/icu/p...
# 11  ../basic_filtered_data/mimic-iv-demo/2.2/icu/p...
# 12  ../basic_filtered_data/mimic-iv-demo/2.2/icu/p...
# 13  ../basic_filtered_data/mimic-iv-demo/2.2/icu/p...
# 14  ../basic_filtered_data/mimic-iv-demo/2.2/icu/p...
# 15  ../basic_filtered_data/mimic-iv-demo/2.2/icu/p...
# 16  ../basic_filtered_data/mimic-iv-demo/2.2/icu/p...
# 17  ../basic_filtered_data/mimic-iv-demo/2.2/icu/p...
# 18  ../basic_filtered_data/mimic-iv-demo/2.2/icu/p...
# 19  ../basic_filtered_data/mimic-iv-demo/2.2/icu/p...
# 20  ../basic_filtered_data/mimic-iv-demo/2.2/icu/p...
# 21  ../basic_filtered_data/mimic-iv-demo/2.2/icu/p...
# 22  ../basic_filtered_data/mimic-iv-demo/2.2/icu/p...
# 23  ../basic_filtered_data/mimic-iv-demo/2.2/icu/p...
# 24  ../basic_filtered_data/mimic-iv-demo/2.2/icu/p...
# 25  ../basic_filtered_data/mimic-iv-demo/2.2/icu/p...
# 26  ../basic_filtered_data/mimic-iv-demo/2.2/icu/p...
# 0   ../basic_filtered_data/mimic-iv-demo/2.2/icu/o...
# 1   ../basic_filtered_data/mimic-iv-demo/2.2/icu/o...
# 2   ../basic_filtered_data/mimic-iv-demo/2.2/icu/o...

# %%
df.to_csv("./output/table_matches_require_manual.csv")

# %%
check = pd.read_csv("../basic_filtered_data/mimic-iv-demo/2.2/hosp/transfers.csv.gz")

# %%
check
# Out:
#       Unnamed: 0  subject_id     hadm_id  transfer_id  eventtype
# 0              0    10009049  22995465.0     30030230  discharge  \
# 1              1    10025612  23403708.0     32533329  discharge
# 2              2    10020786  23488445.0     37922399  discharge
# 3              3    10014078  25809882.0     34694622  discharge
# 4              4    10039831  26924951.0     37155928  discharge
# ...          ...         ...         ...          ...        ...
# 1185        1185    10021118  24490144.0     31983963   transfer
# 1186        1186    10021118  24490144.0     38367109   transfer
# 1187        1187    10021118  24490144.0     39362807   transfer
# 1188        1188    10021118  24490144.0     38425947      admit
# 1189        1189    10021118  24490144.0     36558922   transfer
#
#                                           careunit               intime
# 0                                              NaN  2174-05-31 14:21:47  \
# 1                                              NaN  2125-10-03 12:25:27
# 2                                              NaN  2189-06-13 17:25:44
# 3                                              NaN  2166-08-26 14:49:42
# 4                                              NaN  2116-01-02 14:35:02
# ...                                            ...                  ...
# 1185                                          PACU  2161-11-19 07:16:15
# 1186                               Cardiac Surgery  2161-11-20 21:45:42
# 1187                           Medicine/Cardiology  2161-11-16 19:53:20
# 1188                           Medicine/Cardiology  2161-11-15 20:10:55
# 1189  Cardiac Vascular Intensive Care Unit (CVICU)  2161-11-19 10:04:04
#
#                   outtime
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 1185  2161-11-19 10:04:04
# 1186  2161-11-23 16:06:31
# 1187  2161-11-19 07:16:15
# 1188  2161-11-16 19:53:20
# 1189  2161-11-20 21:45:42
#
# [1190 rows x 8 columns]
